# %%
import models
import pymc as pm
# Out:
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
media = models.load_media()
# media = models.delay(media, lag=7, retention_rate=0.6, retention_length=3, linear_shift=True)
# media = models.delay(media, lag=1, retention_rate=0.6, retention_length=3, linear_shift=False)
# media = models.delayed_adstock(media)
models.plot_media(media)
# Out:
# <Axes: title={'center': 'MMM test data transformed'}, xlabel='start_of_week'>

# %%
model_trend = models.model_trend(media)
models.plot_prior_predictive(model_trend, media)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 model_trend = models.model_trend(media)
#       2 models.plot_prior_predictive(model_trend, media)
#
# File ~/Documents/private/haensel-ams/models.py:62, in model_trend(media)
#      60 weights = pm.Deterministic(f'weights_{channel}',alpha ** ((pt.arange(L)) - theta) ** 2)
#      61 media = pt.as_tensor_variable(media[channel])
# ---> 62 media_transformed = pm.Deterministic(f'media_transformed_{channel}', pm.math.conv2d(media[None, :], weights[::-1][None, :], border_mode='full')[0, :len(media)])
#      63 media_channel = mean_normalize(media_transformed)
#      66 media_channel = pt.as_tensor_variable(media_channel)
#
# AttributeError: module 'pymc.math' has no attribute 'conv2d'

# %%
models.plot_posterior(model_trend, media)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [coefficient_spend_channel_1, coefficient_spend_channel_2, coefficient_spend_channel_3, coefficient_spend_channel_4, coefficient_spend_channel_5, coefficient_spend_channel_6, coefficient_spend_channel_7, capacity_coef, growth_rate, cos_coef, sin_coef, year_coeff, sigma]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Sampling 4 chains for 2_000 tune and 1_000 draw iterations (8_000 + 4_000 draws total) took 10 seconds.
# Sampling: [revenue]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ...
